# %% [markdown]
# # YOLO26m 로컬 학습 노트북

# %%
# Cell 1: GPU 확인
import torch
print('GPU 사용 가능:', torch.cuda.is_available())
print('GPU 이름:', torch.cuda.get_device_name(0))
# Out:
# GPU 사용 가능: True
# GPU 이름: NVIDIA GeForce RTX 2080

# %%
# Cell 2: 작업 폴더 설정
import os
WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26')
os.chdir(WORK_DIR)
print('작업 폴더:', WORK_DIR)
# Out:
# 작업 폴더: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26

# %%
# Cell 3: 파일 확인
import os
WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26')
for item in os.listdir(WORK_DIR):
    print(item)
# Out:
# yolo_local_yolov26_final.ipynb

# %%
# 새 환경이라 roboflow, ultralytics 먼저 설치
import subprocess
subprocess.run(['pip', 'install', 'roboflow', 'ultralytics'], check=True)

# roboflow 라이브러리에서 Roboflow 클래스 불러오기
from roboflow import Roboflow

# API 키로 Roboflow 계정에 로그인
rf = Roboflow(api_key="byjMEhXUKbKas3eLE2V9")

# 워크스페이스(elecourse-atjrg) 안의 프로젝트(merge_0626_3)에 접근
project = rf.workspace("elecourse-atjrg").project("merge_0626_3")

# 해당 프로젝트의 13번 버전 선택
version = project.version(13)

# YOLOv11 형식으로 데이터셋 다운로드 → 인공지능프로젝트 폴더에 저장됨
import os
os.chdir(os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26'))
dataset = version.download("yolov11")
# Out:
# Requirement already satisfied: roboflow in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (1.3.10)
# Requirement already satisfied: ultralytics in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (8.4.80)
# Requirement already satisfied: certifi in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2026.6.17)
# Requirement already satisfied: idna==3.7 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (3.11.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2.4.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (12.2.0)
# Requirement already satisfied: pi-heif<2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.4.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2.34.2)
# Requirement already satisfied: six in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2.7.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (4.68.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (8.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from typer<0.26,>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: torch>=1.8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: psutil>=5.8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (1.42.0)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from matplotlib->roboflow) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from matplotlib->roboflow) (26.0)
# Requirement already satisfied: pyparsing>=3 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: polars-runtime-32==1.42.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from polars>=0.20.0->ultralytics) (1.42.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from requests->roboflow) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: filelock in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: networkx in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in merge_0626_3-13 to yolov11:: 100%|██████████| 140080/140080 [00:09<00:00, 15552.02it/s]
# Extracting Dataset Version Zip to merge_0626_3-13 in yolov11:: 100%|██████████| 6439/6439 [00:00<00:00, 7269.11it/s]

# %%
# 인공지능프로젝트 폴더 안의 파일 목록 확인
import os
for item in os.listdir(os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26')):
    print(item)
# Out:
# yolo_local_yolov26_final.ipynb
# merge_0626_3-13

# %%
# ultralytics에서 YOLO 클래스 불러오기
from ultralytics import YOLO

import os
WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26')

# yolo11m.pt 모델 로드
model = YOLO(os.path.join(WORK_DIR, 'yolo26m.pt'))

# 모델 학습 시작
train_result = model.train(
    data=os.path.join(WORK_DIR, 'merge_0626_3-13/data.yaml'),
    epochs=100,
    imgsz=640,
    batch=16,
    name="dell7920_v1",
    project=os.path.join(WORK_DIR, 'runs/detect')
)

# 학습 결과 폴더에서 best.pt 경로 자동 저장
# (같은 name으로 여러 번 돌리면 dell7920_v1-2, -3 ... 자동 생성되므로 직접 잡아줌)
MODEL_PATH = os.path.join(str(train_result.save_dir), 'weights', 'best.pt')
print('학습된 모델 경로:', MODEL_PATH)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m.pt to '/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/yolo26m.pt': 100% ━━━━━━━━━━━━ 42.2MB 37.8MB/s 1.1s1.1s<0.1s
# New https://pypi.org/project/ultralytics/8.4.83 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.80 🚀 Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 7785MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/yolo26m.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=dell7920_v1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/dell7920_v1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2809410  ultralytics.nn.modules.head.Detect           [7, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 21,783,682 parameters, 21,783,682 gradients, 74.8 GFLOPs
#
# Transferred 756/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 57.2MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1022.0±584.4 MB/s, size: 50.7 KB)
# train: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/train/labels... 2955 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2955/2955 1.5Kit/s 1.9s0.0s
# train: New cache created: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 24, len(boxes) = 8277. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 641.7±272.5 MB/s, size: 40.1 KB)
# val: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/valid/labels... 137 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 137/137 852.5it/s 0.2s3s
# val: New cache created: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 10, len(boxes) = 447. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# Plotting labels to /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/dell7920_v1/labels.jpg...
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/dell7920_v1
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING ⚠️ CUDA out of memory with batch=16. Reducing to batch=8 and retrying (1/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1366.4±688.7 MB/s, size: 54.3 KB)
# train: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/train/labels.cache... 2955 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2955/2955 590.2Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 24, len(boxes) = 8277. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 623.9±499.6 MB/s, size: 42.5 KB)
# val: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/valid/labels.cache... 137 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 137/137 4.3Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 10, len(boxes) = 447. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# : 0% ──────────── 0/185  0.9s
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100     0.848G      1.683      7.483    0.01366         37        640: 1% ──────────── 6/370 2.9it/s 3.0s<2:04WARNING ⚠️ CUDA out of memory with batch=8. Reducing to batch=4 and retrying (2/3).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1036.3±347.7 MB/s, size: 36.7 KB)
# train: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/train/labels.cache... 2955 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2955/2955 1.0Git/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 24, len(boxes) = 8277. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1018.3±385.9 MB/s, size: 52.8 KB)
# val: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/valid/labels.cache... 137 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 137/137 7.1Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 10, len(boxes) = 447. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000909, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
#       1/100     0.848G      1.683      7.483    0.01366         37        640: 1% ──────────── 7/370 2.3it/s 4.1s<2:35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      2.75G      1.611      3.259    0.01818         36        640: 100% ━━━━━━━━━━━━ 739/739 6.1it/s 2:020.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.2it/s 1.5s0.4s
#                    all        137        447      0.553      0.467      0.467      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      2.71G      1.747      2.206    0.02059         21        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.701      0.436      0.463       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      2.71G      1.758      2.051    0.02087         36        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.529      0.517      0.556      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      2.71G       1.76      2.024    0.02159         11        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.771      0.508      0.536      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      2.71G      1.697      1.949    0.02014         12        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.539      0.598      0.615      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      2.71G      1.668      1.816    0.02003          2        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.551      0.639      0.615      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      2.71G      1.611      1.728    0.01885         16        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.5s
#                    all        137        447      0.605      0.623      0.615      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      2.71G      1.555      1.631    0.01821         23        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.705      0.653      0.662      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      2.71G      1.526      1.584    0.01726         10        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.584      0.643      0.658      0.372
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      2.71G      1.507      1.563    0.01738         15        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.782       0.65      0.707      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      2.73G      1.508      1.518    0.01697          8        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.624      0.678      0.689      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      2.71G      1.466      1.478    0.01597          8        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.831      0.592      0.706      0.448
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      2.71G       1.47      1.446    0.01612         14        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.817      0.659      0.734      0.434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      2.71G      1.445      1.457    0.01561         16        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.653      0.735       0.74      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      2.71G      1.434      1.402    0.01589         19        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.5s
#                    all        137        447      0.669      0.744      0.743      0.445
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      2.67G      1.403      1.322    0.01495          7        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.621       0.73      0.736      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      2.71G      1.403      1.349    0.01536          6        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.628      0.749      0.742      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      2.71G       1.38      1.358    0.01501         16        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.718      0.785      0.781      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      2.71G      1.366      1.304    0.01431         23        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.666      0.749      0.765      0.476
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      2.71G      1.362       1.29    0.01449         10        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447       0.72      0.718      0.758      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      2.71G       1.35      1.286    0.01418         15        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.757      0.743      0.804      0.506
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      2.71G       1.34      1.252    0.01418          6        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.597      0.768      0.732      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      2.71G      1.336      1.239    0.01401         15        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.743      0.709      0.758      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      2.71G      1.294      1.156    0.01346         15        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.662      0.768      0.744      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      2.71G      1.305      1.185     0.0138         10        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.677      0.775      0.761      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      2.71G      1.291      1.213    0.01327          4        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447       0.74      0.729      0.764      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      2.73G      1.278       1.17    0.01335         12        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.725      0.735      0.758      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      2.71G      1.279      1.165    0.01355         28        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.702      0.744      0.741      0.487
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      2.71G      1.282       1.12    0.01357          8        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.699       0.76      0.772      0.496
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      2.71G      1.257      1.134    0.01305         20        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.655      0.788      0.774       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      2.71G      1.239      1.084    0.01261         20        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.728      0.727      0.769      0.497
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      2.67G       1.24      1.101     0.0129         14        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.5s
#                    all        137        447      0.723      0.719      0.742        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      2.71G      1.235      1.104    0.01242         16        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447        0.7      0.753      0.789      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      2.71G      1.235      1.085    0.01294         32        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.698      0.652      0.715      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      2.71G       1.21      1.052    0.01233         10        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.753      0.787      0.813      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      2.71G      1.196      1.012    0.01244         15        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.713      0.781      0.788      0.519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      2.71G      1.186       1.02    0.01214         33        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447       0.74      0.767      0.775      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      2.71G      1.174     0.9936    0.01201         12        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.692      0.777       0.77      0.526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      2.71G      1.179     0.9924    0.01148         18        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.748      0.761      0.788      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      2.71G      1.172      0.964    0.01165         13        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.669       0.77       0.76      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      2.71G      1.164     0.9752     0.0118         17        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.748      0.751      0.765      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      2.71G       1.14     0.9541    0.01139         14        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.5s
#                    all        137        447      0.775      0.747      0.786      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      2.73G      1.156     0.9583    0.01138          8        640: 100% ━━━━━━━━━━━━ 739/739 6.3it/s 1:580.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.771      0.747      0.795      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      2.71G      1.144     0.9162    0.01151         10        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.793      0.769      0.811      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      2.71G       1.14     0.9364    0.01136         11        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.776      0.758      0.793       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      2.71G      1.117     0.9323    0.01117          5        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.763       0.81      0.816      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      2.71G       1.12     0.9173    0.01105         26        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.809      0.764      0.815      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      2.67G      1.116     0.9207    0.01076         17        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:530.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447       0.76      0.768      0.799      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      2.71G      1.112     0.8692    0.01109          3        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.795      0.753      0.806      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      2.71G      1.109     0.8684    0.01079         16        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.725      0.764      0.757       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      2.71G      1.074     0.8531    0.01061         22        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.842       0.73      0.783       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      2.71G      1.078     0.8698     0.0105         11        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:560.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.784       0.76      0.793      0.538
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      2.71G      1.073     0.8381    0.01037         18        640: 100% ━━━━━━━━━━━━ 739/739 6.3it/s 1:570.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.776      0.755      0.789      0.529
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      2.71G      1.074     0.8572    0.01043         26        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:560.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.748      0.813      0.803      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      2.73G      1.081     0.8505     0.0106         12        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.767       0.75      0.809      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      2.71G      1.049     0.8081    0.01018         11        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.787        0.8      0.819      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      2.71G      1.056     0.8321    0.01011         13        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.786      0.809      0.813      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      2.71G      1.047     0.7975    0.01033         22        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.818      0.798      0.832      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      2.73G      1.038     0.8017    0.00989         20        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.795      0.799      0.813      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      2.71G      1.023     0.7967   0.009907         17        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.786      0.769      0.815       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      2.71G      1.012     0.8008   0.009952         12        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.774       0.78      0.814       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      2.71G      1.004     0.7569     0.0097         11        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.775      0.765      0.774      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      2.73G      1.014     0.7709   0.009723          8        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.797      0.747      0.799      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      2.67G     0.9932     0.7658   0.009587          9        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.761      0.805      0.818      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      2.71G       1.01     0.7529   0.009661          6        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.808      0.784      0.803      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      2.71G     0.9814     0.7325    0.00931         16        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447       0.85      0.817      0.849      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      2.71G     0.9851     0.7342   0.009374          5        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.781      0.801      0.813      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      2.71G      0.986     0.7232   0.009315         11        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.816      0.799      0.828      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      2.71G      0.968      0.712   0.009387         13        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.787      0.798      0.803      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      2.71G      0.959     0.7173   0.009097         33        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.811      0.799      0.811      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      2.71G     0.9358      0.695   0.008794         26        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.829      0.765      0.821       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      2.71G     0.9449     0.6941   0.008867          7        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.815      0.755      0.782      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      2.71G     0.9447       0.69   0.009018          5        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.807       0.77      0.807      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      2.71G     0.9308     0.6892   0.008637          9        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:530.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.811      0.771      0.811      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      2.73G     0.9251     0.6696    0.00886         19        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:520.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.825      0.802       0.82      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      2.71G     0.9162     0.6688   0.008674         23        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:530.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.811      0.765      0.799      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      2.71G     0.9194     0.6712   0.008647         14        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.807      0.767      0.781      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      2.71G     0.9105     0.6602   0.008459          7        640: 100% ━━━━━━━━━━━━ 739/739 6.6it/s 1:530.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.832      0.756      0.792      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      2.71G     0.9021      0.668   0.008321         28        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.814       0.79      0.819      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      2.67G     0.9009     0.6627   0.008476          8        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.802       0.79      0.802      0.555
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      2.71G     0.9049     0.6493   0.008429         27        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.848      0.796      0.816      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      2.71G      0.877     0.6395   0.008191         13        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.803      0.796      0.817       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      2.71G     0.8828     0.6439   0.008222         14        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.827      0.786      0.811      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      2.71G     0.8701     0.6371    0.00825         11        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.794      0.785      0.807      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      2.71G     0.8891     0.6364   0.007899          5        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.799       0.79      0.801      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      2.71G     0.8599     0.6452   0.008038         17        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.821       0.77      0.799       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      2.71G     0.8644     0.6322   0.007999          8        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.803      0.774      0.798      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      2.71G     0.8534     0.6193   0.007788         13        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.805      0.757      0.791      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      2.71G     0.8489      0.609   0.007832          9        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:560.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.804      0.773      0.786      0.557
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      2.71G     0.8476     0.6245   0.007852         16        640: 100% ━━━━━━━━━━━━ 739/739 6.3it/s 1:570.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.818      0.769      0.799      0.561
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      2.73G     0.7551     0.4441   0.008405          6        640: 100% ━━━━━━━━━━━━ 739/739 6.3it/s 1:580.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.5s
#                    all        137        447      0.831      0.753      0.789      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      2.71G      0.744     0.4357   0.008284          5        640: 100% ━━━━━━━━━━━━ 739/739 6.3it/s 1:580.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.802      0.756      0.773      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      2.71G     0.7318     0.4263   0.007971         16        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.5s
#                    all        137        447      0.848      0.737      0.788      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      2.71G     0.7346     0.4217   0.007866          3        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.829      0.753      0.779      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      2.71G      0.728     0.4214   0.008016          5        640: 100% ━━━━━━━━━━━━ 739/739 6.5it/s 1:540.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.826      0.767      0.793      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      2.67G     0.7175     0.4145   0.007779          6        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.819      0.769      0.788       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      2.71G     0.7127     0.4127   0.007543         15        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.836      0.765      0.789      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      2.71G     0.7097     0.4214    0.00772          8        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.804      0.785      0.793      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      2.71G     0.7059     0.4175   0.007645          9        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.4it/s 1.5s0.4s
#                    all        137        447      0.815      0.759       0.78      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      2.71G     0.7035     0.4088    0.00763         10        640: 100% ━━━━━━━━━━━━ 739/739 6.4it/s 1:550.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 3.3it/s 1.5s0.4s
#                    all        137        447      0.823      0.766      0.792      0.552
#
# 100 epochs completed in 3.260 hours.
# Optimizer stripped from /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/dell7920_v1/weights/last.pt, 44.1MB
# Optimizer stripped from /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/dell7920_v1/weights/best.pt, 44.1MB
#
# Validating /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/dell7920_v1/weights/best.pt...
# Ultralytics 8.4.80 🚀 Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 7785MiB)
# YOLO26m summary (fused): 132 layers, 20,354,849 parameters, 0 gradients, 67.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.8it/s 1.8s0.5s
#                    all        137        447      0.842       0.82      0.849      0.576
#                    GPU         18         23      0.721      0.652       0.74      0.378
#                    RAM         52         76      0.907      0.816      0.859      0.681
#               RAM_slot         34        220      0.682      0.414      0.471        0.2
#                 eraser         25         25      0.934          1      0.983      0.808
#                   hand         42         71      0.915      0.913      0.955      0.716
#                monitor         14         14      0.861          1      0.995       0.83
#       power_button_LED         18         18      0.877      0.944      0.942      0.415
# Speed: 0.2ms preprocess, 8.0ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/dell7920_v1
# 학습된 모델 경로: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/dell7920_v1/weights/best.pt

# %%
# 학습 결과 mAP 점수 확인 (best.pt 기준)
from ultralytics import YOLO
import os

WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26')

# MODEL_PATH가 앞 셀에서 자동 설정된 경우 그대로 사용,
# 이 셀만 단독 실행할 경우 아래 경로를 직접 입력
if 'MODEL_PATH' not in dir():
    MODEL_PATH = os.path.join(WORK_DIR, 'runs/detect/dell7920_v1/weights/best.pt')  # ← 필요 시 수정

best_model = YOLO(MODEL_PATH)
metrics = best_model.val(data=os.path.join(WORK_DIR, 'merge_0626_3-13/data.yaml'))
print('mAP@50:', metrics.box.map50)
print('mAP@50-95:', metrics.box.map)
# 0.8 이상 → 좋음
# 0.5~0.8 → 데이터 추가 필요
# 0.5 미만 → 라벨링 품질 점검 필요
# Out:
# Ultralytics 8.4.80 🚀 Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080, 7785MiB)
# YOLO26m summary (fused): 132 layers, 20,354,849 parameters, 0 gradients, 67.9 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1126.6±311.8 MB/s, size: 34.5 KB)
# val: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/merge_0626_3-13/valid/labels.cache... 137 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 137/137 47.9Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 10, len(boxes) = 447. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.0it/s 3.0s0.3ss
#                    all        137        447      0.848      0.819      0.849      0.575
#                    GPU         18         23      0.728      0.652       0.74      0.378
#                    RAM         52         76      0.915      0.816      0.859      0.682
#               RAM_slot         34        220      0.702      0.409      0.471        0.2
#                 eraser         25         25      0.935          1      0.983      0.808
#                   hand         42         71      0.915      0.911      0.955      0.717
#                monitor         14         14      0.863          1      0.995      0.827
#       power_button_LED         18         18      0.875      0.944      0.942      0.415
# Speed: 2.3ms preprocess, 14.4ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo26/runs/detect/val
# mAP@50: 0.8493229952926274
# mAP@50-95: 0.5753992213183888

# %% [markdown]
# ## 추론: 이미지에 바운딩 박스 시각화
#
# 학습된 best.pt 모델로 이미지를 추론하고, VSCode 환경에서 결과를 인라인 이미지로 확인합니다.

# %%
# %matplotlib inline

# %%
import os

WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')

if 'MODEL_PATH' not in dir():
    MODEL_PATH = os.path.join(WORK_DIR, 'runs/detect/dell7920_v1/weights/best.pt')  # ← 필요 시 수정

IMAGE_PATH = '/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/20260628_190121.jpg'
CONF_THRESHOLD = 0.25

print('모델 경로:', MODEL_PATH)
print('이미지 경로:', IMAGE_PATH)
print('모델 파일 존재:', os.path.exists(MODEL_PATH))
print('이미지 파일 존재:', os.path.exists(IMAGE_PATH))

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt


model = YOLO(MODEL_PATH)
print('모델 로드 완료')

results = model.predict(
    source=IMAGE_PATH,
    conf=CONF_THRESHOLD,
    save=True,
    project=os.path.join(WORK_DIR, 'inference_out'),
    name='images',
    exist_ok=True,
    verbose=False,  # YOLO 자체 출력 끄기
    show=False      # YOLO 자체 미리보기 끄기
)
result = results[0]
img_rgb = result.plot()[:, :, ::-1]  # BGR → RGB

fig, ax = plt.subplots(figsize=(12, 8))
ax.imshow(img_rgb)
ax.axis('off')
ax.set_title(f'탐지 결과  |  conf ≥ {CONF_THRESHOLD}', fontsize=13, pad=10)
plt.tight_layout()
plt.show()

print('저장 위치:', os.path.join(WORK_DIR, 'inference_out/images/'))
plt.show()

# %%
CLASS_NAMES = model.names

boxes = result.boxes
if boxes is None or len(boxes) == 0:
    print('탐지된 객체 없음')
else:
    print(f'총 {len(boxes)}개 객체 탐지됨\n')
    print(f'{"#":<4} {"클래스":<20} {"신뢰도":>8}  {"바운딩 박스 (x1,y1,x2,y2)"}')
    print('-' * 65)
    for i, box in enumerate(boxes):
        cls_id   = int(box.cls[0])
        conf_val = float(box.conf[0])
        x1, y1, x2, y2 = [round(float(v), 1) for v in box.xyxy[0]]
        print(f'{i+1:<4} {CLASS_NAMES[cls_id]:<20} {conf_val:>7.1%}  ({x1}, {y1}, {x2}, {y2})')

# %% [markdown]
# ## 추론: 영상(Video)에 바운딩 박스 시각화

# %%
# Cell: 영상 추론 설정
import os

WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')

# 학습 셀을 실행했다면 MODEL_PATH가 자동으로 설정되어 있음
# 이 셀만 단독 실행할 경우 아래 경로를 직접 입력
if 'MODEL_PATH' not in dir():
    MODEL_PATH = os.path.join(WORK_DIR, 'runs/detect/dell7920_v1/weights/best.pt')  # ← 필요 시 수정

# 추론할 영상 경로 (mp4, mov, avi 등)
VIDEO_PATH = os.path.join(WORK_DIR, 'test_video.mp4')  # ← 여기에 실제 영상 경로 입력

# 결과 영상 저장 폴더
VIDEO_OUT_DIR = os.path.join(WORK_DIR, 'video_out')
os.makedirs(VIDEO_OUT_DIR, exist_ok=True)

CONF_THRESHOLD = 0.25

print('모델 경로 :', MODEL_PATH)
print('영상 경로 :', VIDEO_PATH)
print('결과 저장 :', VIDEO_OUT_DIR)
print('모델 존재 :', os.path.exists(MODEL_PATH))
print('영상 존재 :', os.path.exists(VIDEO_PATH))

# %%
# Cell: 영상 추론 실행 → 결과 영상 저장
# 처리 완료 후 VIDEO_OUT_DIR/run/ 안에 박스 그려진 mp4가 생성됩니다
from ultralytics import YOLO

model = YOLO(MODEL_PATH)

results = model.predict(
    source=VIDEO_PATH,
    conf=CONF_THRESHOLD,
    save=True,            # 결과 영상 저장
    project=VIDEO_OUT_DIR,
    name='run',
    exist_ok=True,
    verbose=True,
    stream=True           # 메모리 절약: 프레임을 한 번에 다 올리지 않고 스트리밍
)

# stream=True 이면 generator이므로 순회해야 실제로 처리됨
frame_count = 0
for r in results:
    frame_count += 1

print(f'\n처리 완료: {frame_count}프레임')
print(f'결과 저장 위치: {VIDEO_OUT_DIR}/run/')

# %%
# Cell: 결과 영상에서 대표 프레임 미리보기 (균등 간격으로 N장)
import cv2
import glob
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')

PREVIEW_N = 6  # 미리볼 프레임 수

# 저장된 결과 영상 찾기
saved_videos = glob.glob(os.path.join(VIDEO_OUT_DIR, 'run', '*.mp4')) + \
               glob.glob(os.path.join(VIDEO_OUT_DIR, 'run', '*.avi'))

if not saved_videos:
    print('결과 영상을 찾을 수 없습니다. 위 셀을 먼저 실행하세요.')
else:
    out_video_path = saved_videos[0]
    print('미리보기 대상:', out_video_path)

    cap = cv2.VideoCapture(out_video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps          = cap.get(cv2.CAP_PROP_FPS)
    w            = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h            = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    print(f'총 프레임: {total_frames}  |  FPS: {fps:.1f}  |  해상도: {w}x{h}')

    # 균등 간격 프레임 인덱스 선택
    indices = [int(total_frames * i / PREVIEW_N) for i in range(PREVIEW_N)]

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if ret:
            frames.append((idx, frame[:, :, ::-1]))  # BGR → RGB
    cap.release()

    cols = 3
    rows = (len(frames) + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(6 * cols, 4 * rows))
    axes = axes.flatten() if rows > 1 else [axes] if cols == 1 else axes.flatten()

    for i, (ax, (idx, img)) in enumerate(zip(axes, frames)):
        ax.imshow(img)
        ax.axis('off')
        t = idx / fps if fps > 0 else 0
        ax.set_title(f'frame {idx}  ({t:.1f}s)', fontsize=9)

    for ax in axes[len(frames):]:
        ax.set_visible(False)

    plt.suptitle(f'결과 영상 미리보기  |  conf ≥ {CONF_THRESHOLD}', fontsize=12, y=1.01)
    plt.tight_layout()
    plt.show()

# %%
# Cell: 웹캠 실시간 추론 (선택 사항)
# VSCode 터미널에서 실행하는 것을 권장합니다.
# Jupyter 셀에서 실행하면 창이 열리지 않을 수 있습니다.
#
# 사용법: 아래 코드 블록의 주석을 해제하고 실행하세요.
# 종료: 영상 창에서 'q' 키를 누르세요.

# import cv2
# from ultralytics import YOLO
#
# model = YOLO(MODEL_PATH)
#
# cap = cv2.VideoCapture(0)  # 0 = 기본 웹캠, 1·2 = 외부 카메라
# cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
# cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
#
# print('웹캠 추론 시작 — 창에서 q 키를 눌러 종료')
# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     results = model.predict(frame, conf=CONF_THRESHOLD, verbose=False)
#     annotated = results[0].plot()
#
#     cv2.imshow('YOLO11m 실시간 추론  (q: 종료)', annotated)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
#
# cap.release()
# cv2.destroyAllWindows()
# print('종료')

print('웹캠 셀은 주석 처리된 상태입니다.')
print('사용하려면 위 주석(#)을 모두 해제하고 실행하세요.')
