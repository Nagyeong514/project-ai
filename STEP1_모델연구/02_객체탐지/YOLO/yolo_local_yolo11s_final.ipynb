# %% [markdown]
# # YOLOv11 로컬 학습 노트북

# %%
# Cell 1: GPU 확인
import torch
print('GPU 사용 가능:', torch.cuda.is_available())
print('GPU 이름:', torch.cuda.get_device_name(0))
# Out:
# GPU 사용 가능: True
# GPU 이름: NVIDIA GeForce RTX 2080 SUPER

# %%
# Cell 2: 작업 폴더 설정
import os
WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')
os.chdir(WORK_DIR)
print('작업 폴더:', WORK_DIR)
# Out:
# 작업 폴더: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629

# %%
# Cell 3: 파일 확인
import os
WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')
for item in os.listdir(WORK_DIR):
    print(item)
# Out:
# runs

# %%
# 새 환경이라 roboflow, ultralytics 먼저 설치
import subprocess
subprocess.run(['pip', 'install', 'roboflow', 'ultralytics'], check=True)

# roboflow 라이브러리에서 Roboflow 클래스 불러오기
from roboflow import Roboflow

# API 키로 Roboflow 계정에 로그인
rf = Roboflow(api_key="byjMEhXUKbKas3eLE2V9")

# 워크스페이스(elecourse-atjrg) 안의 프로젝트(merge_0626_3)에 접근
project = rf.workspace("elecourse-atjrg").project("merge_0626_3")

# 해당 프로젝트의 13번 버전 선택
version = project.version(13)

# YOLOv11 형식으로 데이터셋 다운로드 → 인공지능프로젝트 폴더에 저장됨
import os
os.chdir(os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629'))
dataset = version.download("yolov11")
# Out:
# Requirement already satisfied: roboflow in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (1.3.10)
# Requirement already satisfied: ultralytics in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (8.4.83)
# Requirement already satisfied: certifi in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2026.6.17)
# Requirement already satisfied: idna==3.7 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (3.11.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2.4.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (12.2.0)
# Requirement already satisfied: pi-heif<2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.4.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.5.5)
# Requirement already satisfied: python-dateutil in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.2.2)
# Requirement already satisfied: requests in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2.34.2)
# Requirement already satisfied: six in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (2.7.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (4.68.3)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from roboflow) (8.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from typer<0.26,>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: torch>=1.8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: psutil>=5.8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (7.2.2)
# Requirement already satisfied: polars>=0.20.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (1.42.1)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from ultralytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from matplotlib->roboflow) (4.63.0)
# Requirement already satisfied: packaging>=20.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from matplotlib->roboflow) (26.0)
# Requirement already satisfied: pyparsing>=3 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: polars-runtime-32==1.42.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from polars>=0.20.0->ultralytics) (1.42.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from requests->roboflow) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: filelock in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: networkx in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/piai/anaconda3/envs/yolo_env/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in merge_0626_3-13 to yolov11:: 100%|██████████| 140080/140080 [00:08<00:00, 16397.17it/s]
# Extracting Dataset Version Zip to merge_0626_3-13 in yolov11:: 100%|██████████| 6439/6439 [00:00<00:00, 9724.79it/s]

# %%
# 인공지능프로젝트 폴더 안의 파일 목록 확인
import os
for item in os.listdir(os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')):
    print(item)
# Out:
# runs
# merge_0626_3-13

# %%
# ultralytics에서 YOLO 클래스 불러오기
from ultralytics import YOLO

import os
WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')

# yolo11s.pt 모델 로드
model = YOLO(os.path.join(WORK_DIR, 'yolo11s.pt'))

# 모델 학습 시작
train_result = model.train(
    data=os.path.join(WORK_DIR, 'merge_0626_3-13/data.yaml'),
    epochs=100,
    imgsz=640,
    batch=16,
    name="dell7920_v1",
    project=os.path.join(WORK_DIR, 'runs/detect')
)

# 학습 결과 폴더에서 best.pt 경로 자동 저장
# (같은 name으로 여러 번 돌리면 dell7920_v1-2, -3 ... 자동 생성되므로 직접 잡아줌)
MODEL_PATH = os.path.join(str(train_result.save_dir), 'weights', 'best.pt')
print('학습된 모델 경로:', MODEL_PATH)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/piai/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11s.pt to '/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 33.1MB/s 0.6s0.5s<0.1s
# Ultralytics 8.4.83 🚀 Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 SUPER, 7785MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/merge_0626_3-13/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dis=6.0, distill_model=None, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/yolo11s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=dell7920_v1-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect/dell7920_v1-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/piai/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 19.1MB/s 0.0s
# Overriding model.yaml nc=80 with nc=7
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    822117  ultralytics.nn.modules.head.Detect           [7, 16, None, [128, 256, 512]]
# YOLO11s summary: 182 layers, 9,430,501 parameters, 9,430,485 gradients, 21.6 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 30.8MB/s 0.2s.1s<0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1969.8±758.6 MB/s, size: 50.7 KB)
# train: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/merge_0626_3-13/train/labels... 2955 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2955/2955 846.9it/s 3.5s0.1s
# train: New cache created: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/merge_0626_3-13/train/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) =
640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.6it/s 0.8s0.2s
#                    all        137        447      0.812      0.819      0.837      0.569
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.03G     0.7254     0.4724     0.9826         36        640: 100% ━━━━━━━━━━━━ 185/185 5.6it/s 32.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.6it/s 0.8s0.2s
#                    all        137        447       0.79      0.825      0.829      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      3.98G     0.7081      0.463     0.9729         17        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.6it/s 0.8s0.2s
#                    all        137        447      0.787      0.817      0.827      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.06G     0.7057     0.4559     0.9747         41        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.6it/s 0.8s0.2s
#                    all        137        447      0.801      0.806      0.818       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.02G     0.6967     0.4545     0.9668         35        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.6it/s 0.8s0.2s
#                    all        137        447      0.799      0.829      0.835      0.564
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.05G     0.6806     0.4432     0.9634         21        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.4it/s 0.8s0.2s
#                    all        137        447      0.806      0.822      0.834       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100         4G     0.6794     0.4435     0.9597         27        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.6s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.4it/s 0.8s0.2s
#                    all        137        447      0.814      0.828      0.833      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.05G     0.6779     0.4427     0.9626         32        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.4it/s 0.8s0.2s
#                    all        137        447      0.812      0.822      0.824      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.03G     0.6716     0.4419     0.9548         35        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.5it/s 0.8s0.2s
#                    all        137        447      0.803      0.821      0.828      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.04G     0.6636     0.4387     0.9555         35        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.6it/s 0.8s0.2s
#                    all        137        447      0.807      0.813      0.824      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100         4G     0.6597     0.4369     0.9551         34        640: 100% ━━━━━━━━━━━━ 185/185 5.7it/s 32.7s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 6.6it/s 0.8s0.2s
#                    all        137        447      0.811      0.812      0.825      0.569
#
# 100 epochs completed in 0.952 hours.
# Optimizer stripped from /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect/dell7920_v1-2/weights/last.pt, 19.2MB
# Optimizer stripped from /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect/dell7920_v1-2/weights/best.pt, 19.2MB
#
# Validating /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect/dell7920_v1-2/weights/best.pt...
# Ultralytics 8.4.83 🚀 Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 SUPER, 7785MiB)
# YOLO11s summary (fused): 101 layers, 9,415,509 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.7it/s 1.8s0.4s
#                    all        137        447      0.791      0.779      0.845      0.584
#                    GPU         18         23      0.668      0.609      0.722      0.434
#                    RAM         52         76      0.937      0.803      0.871       0.67
#               RAM_slot         34        220      0.651      0.306      0.454      0.211
#                 eraser         25         25      0.922       0.96      0.991      0.819
#                   hand         42         71      0.841      0.958      0.967       0.71
#                monitor         14         14      0.728      0.929      0.967      0.784
#       power_button_LED         18         18      0.793      0.889      0.943      0.461
# Speed: 0.2ms preprocess, 4.9ms inference, 0.0ms loss, 4.9ms postprocess per image
# Results saved to /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect/dell7920_v1-2
# 학습된 모델 경로: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect/dell7920_v1-2/weights/best.pt

# %%
# 학습 결과 mAP 점수 확인 (best.pt 기준)
from ultralytics import YOLO
import os

WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')

# MODEL_PATH가 앞 셀에서 자동 설정된 경우 그대로 사용,
# 이 셀만 단독 실행할 경우 아래 경로를 직접 입력
if 'MODEL_PATH' not in dir():
    MODEL_PATH = os.path.join(WORK_DIR, 'runs/detect/dell7920_v1/weights/best.pt')  # ← 필요 시 수정

best_model = YOLO(MODEL_PATH)
metrics = best_model.val(data=os.path.join(WORK_DIR, 'merge_0626_3-13/data.yaml'))
print('mAP@50:', metrics.box.map50)
print('mAP@50-95:', metrics.box.map)
# 0.8 이상 → 좋음
# 0.5~0.8 → 데이터 추가 필요
# 0.5 미만 → 라벨링 품질 점검 필요
# Out:
# Ultralytics 8.4.83 🚀 Python-3.11.15 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 SUPER, 7785MiB)
# YOLO11s summary (fused): 101 layers, 9,415,509 parameters, 0 gradients, 21.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1839.8±727.6 MB/s, size: 41.5 KB)
# val: Scanning /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/merge_0626_3-13/valid/labels.cache... 137 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 137/137 57.5Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 10, len(boxes) = 447. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 9/9 3.5it/s 2.6s0.2s
#                    all        137        447      0.783      0.797      0.845      0.583
#                    GPU         18         23       0.66      0.652      0.721      0.433
#                    RAM         52         76      0.926      0.803      0.871       0.67
#               RAM_slot         34        220      0.622      0.377      0.455       0.21
#                 eraser         25         25      0.924      0.971      0.992      0.816
#                   hand         42         71      0.835      0.958      0.967      0.709
#                monitor         14         14      0.724      0.929      0.967      0.776
#       power_button_LED         18         18      0.788      0.889      0.942      0.466
# Speed: 2.0ms preprocess, 8.7ms inference, 0.0ms loss, 4.2ms postprocess per image
# Results saved to /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect/val
# mAP@50: 0.8450428067537679
# mAP@50-95: 0.5830017713939873

# %% [markdown]
# ## 추론: 이미지에 바운딩 박스 시각화
#
# 학습된 best.pt 모델로 이미지를 추론하고, VSCode 환경에서 결과를 인라인 이미지로 확인합니다.

# %%
# %matplotlib inline

# %%
import os

WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')

if 'MODEL_PATH' not in dir():
    MODEL_PATH = os.path.join(WORK_DIR, 'runs/detect/dell7920_v1/weights/best.pt')  # ← 필요 시 수정

IMAGE_PATH = '/home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/20260628_190121.jpg'
CONF_THRESHOLD = 0.25

print('모델 경로:', MODEL_PATH)
print('이미지 경로:', IMAGE_PATH)
print('모델 파일 존재:', os.path.exists(MODEL_PATH))
print('이미지 파일 존재:', os.path.exists(IMAGE_PATH))
# Out:
# 모델 경로: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629/runs/detect/dell7920_v1-2/weights/best.pt
# 이미지 경로: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/20260628_190121.jpg
# 모델 파일 존재: True
# 이미지 파일 존재: False

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt


model = YOLO(MODEL_PATH)
print('모델 로드 완료')

results = model.predict(
    source=IMAGE_PATH,
    conf=CONF_THRESHOLD,
    save=True,
    project=os.path.join(WORK_DIR, 'inference_out'),
    name='images',
    exist_ok=True,
    verbose=False,  # YOLO 자체 출력 끄기
    show=False      # YOLO 자체 미리보기 끄기
)
result = results[0]
img_rgb = result.plot()[:, :, ::-1]  # BGR → RGB

fig, ax = plt.subplots(figsize=(12, 8))
ax.imshow(img_rgb)
ax.axis('off')
ax.set_title(f'탐지 결과  |  conf ≥ {CONF_THRESHOLD}', fontsize=13, pad=10)
plt.tight_layout()
plt.show()

print('저장 위치:', os.path.join(WORK_DIR, 'inference_out/images/'))
plt.show()
# Out:
# 모델 로드 완료
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 8
#       4
#       5 model = YOLO(MODEL_PATH)
#       6 print('모델 로드 완료')
#       7
# ----> 8 results = model.predict(
#       9     source=IMAGE_PATH,
#      10     conf=CONF_THRESHOLD,
#      11     save=True,
#
# File ~/anaconda3/envs/yolo_env/lib/python3.11/site-packages/ultralytics/engine/model.py:541, in Model.predict(self, source, stream, predictor, **kwargs)
#     539 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     540     self.predictor.set_prompts(prompts)
# --> 541 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/anaconda3/envs/yolo_env/lib/python3.11/site-packages/ultralytics/engine/predictor.py:228, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     226     return self.stream_inference(source, model, *args, **kwargs)
#     227 else:
# --> 228     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File ~/anaconda3/envs/yolo_env/lib/python3.11/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File ~/anaconda3/envs/yolo_env/lib/python3.11/site-packages/ultralytics/engine/predictor.py:302, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     298     self.setup_model(model)
#     300 with self._lock:  # for thread-safe inference
#     301     # Setup source every time predict is called
# --> 302     self.setup_source(source if source is not None else self.args.source)
#     304     # Check if save_dir/ label file exists
#     305     if self.args.save or self.args.save_txt:
#
# File ~/anaconda3/envs/yolo_env/lib/python3.11/site-packages/ultralytics/engine/predictor.py:259, in BasePredictor.setup_source(self, source, stride)
#     251 """Set up source and inference mode.
#     252
#     253 Args:
#    (...)    256     stride (int, optional): Model stride for image size checking.
#     257 """
#     258 self.imgsz = check_imgsz(self.args.imgsz, stride=stride or self.model.stride, min_dim=2)  # check image size
# --> 259 self.dataset = load_inference_source(
#     260     source=source,
#     261     batch=self.args.batch,
#     262     vid_stride=self.args.vid_stride,
#     263     buffer=self.args.stream_buffer,
#     264     channels=getattr(self.model, "channels", 3),
#     265 )
#     266 self.source_type = self.dataset.source_type
#     267 if (
#     268     self.source_type.stream
#     269     or self.source_type.screenshot
#     270     or len(self.dataset) > 1000  # many images
#     271     or any(getattr(self.dataset, "video_flag", [False]))
#     272 ):  # long sequence
#
# File ~/anaconda3/envs/yolo_env/lib/python3.11/site-packages/ultralytics/data/build.py:458, in load_inference_source(source, batch, vid_stride, buffer, channels)
#     456     dataset = LoadPilAndNumpy(source, channels=channels)
#     457 else:
# --> 458     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride, channels=channels)
#     460 # Attach source types to the dataset
#     461 setattr(dataset, "source_type", source_type)
#
# File ~/anaconda3/envs/yolo_env/lib/python3.11/site-packages/ultralytics/data/loaders.py:374, in LoadImagesAndVideos.__init__(self, path, batch, vid_stride, channels)
#     372         files.append(str((parent / p).absolute()))  # files (relative to *.txt file parent)
#     373     else:
# --> 374         raise FileNotFoundError(f"{p} does not exist")
#     376 # Define files as images or videos
#     377 images, videos = [], []
#
# FileNotFoundError: /home/piai/다운로드/인공지능프로젝트/YOLO_jupyters/20260628_190121.jpg does not exist

# %%
CLASS_NAMES = model.names

boxes = result.boxes
if boxes is None or len(boxes) == 0:
    print('탐지된 객체 없음')
else:
    print(f'총 {len(boxes)}개 객체 탐지됨\n')
    print(f'{"#":<4} {"클래스":<20} {"신뢰도":>8}  {"바운딩 박스 (x1,y1,x2,y2)"}')
    print('-' * 65)
    for i, box in enumerate(boxes):
        cls_id   = int(box.cls[0])
        conf_val = float(box.conf[0])
        x1, y1, x2, y2 = [round(float(v), 1) for v in box.xyxy[0]]
        print(f'{i+1:<4} {CLASS_NAMES[cls_id]:<20} {conf_val:>7.1%}  ({x1}, {y1}, {x2}, {y2})')
# Out:
# 총 9개 객체 탐지됨
#
# #    클래스                       신뢰도  바운딩 박스 (x1,y1,x2,y2)
# -----------------------------------------------------------------
# 1    GPU                    52.0%  (1332.6, 535.8, 3907.2, 935.7)
# 2    GPU                    51.8%  (1292.4, 174.9, 3845.6, 541.1)
# 3    RAM_slot               37.0%  (664.9, 1501.1, 1720.1, 1586.9)
# 4    RAM_slot               36.0%  (665.1, 1367.5, 1726.0, 1446.8)
# 5    RAM_slot               34.9%  (661.4, 1260.7, 1719.8, 1334.4)
# 6    RAM_slot               33.0%  (667.0, 1452.0, 1722.9, 1533.2)
# 7    RAM_slot               30.0%  (664.4, 1388.5, 1724.3, 1480.9)
# 8    RAM_slot               29.1%  (646.5, 1319.7, 1733.7, 1388.9)
# 9    RAM_slot               28.7%  (643.8, 1460.8, 1729.8, 1555.0)

# %% [markdown]
# ## 추론: 영상(Video)에 바운딩 박스 시각화

# %%
# Cell: 영상 추론 설정
import os

WORK_DIR = os.path.expanduser('~/다운로드/인공지능프로젝트/YOLO_jupyters/yolo_local_v13_0629')

# 학습 셀을 실행했다면 MODEL_PATH가 자동으로 설정되어 있음
# 이 셀만 단독 실행할 경우 아래 경로를 직접 입력
if 'MODEL_PATH' not in dir():
    MODEL_PATH = os.path.join(WORK_DIR, 'runs/detect/dell7920_v1/weights/best.pt')  # ← 필요 시 수정

# 추론할 영상 경로 (mp4, mov, avi 등)
VIDEO_PATH = os.path.join(WORK_DIR, 'test_video.mp4')  # ← 여기에 실제 영상 경로 입력

# 결과 영상 저장 폴더
VIDEO_OUT_DIR = os.path.join(WORK_DIR, 'video_out')
os.makedirs(VIDEO_OUT_DIR, exist_ok=True)

CONF_THRESHOLD = 0.25

print('모델 경로 :', MODEL_PATH)
print('영상 경로 :', VIDEO_PATH)
print('결과 저장 :', VIDEO_OUT_DIR)
print('모델 존재 :', os.path.exists(MODEL_PATH))
print('영상 존재 :', os.path.exists(VIDEO_PATH))

# %%
# Cell: 영상 추론 실행 → 결과 영상 저장
# 처리 완료 후 VIDEO_OUT_DIR/run/ 안에 박스 그려진 mp4가 생성됩니다
from ultralytics import YOLO

model = YOLO(MODEL_PATH)

results = model.predict(
    source=VIDEO_PATH,
    conf=CONF_THRESHOLD,
    save=True,            # 결과 영상 저장
    project=VIDEO_OUT_DIR,
    name='run',
    exist_ok=True,
    verbose=True,
    stream=True           # 메모리 절약: 프레임을 한 번에 다 올리지 않고 스트리밍
)

# stream=True 이면 generator이므로 순회해야 실제로 처리됨
frame_count = 0
for r in results:
    frame_count += 1

print(f'\n처리 완료: {frame_count}프레임')
print(f'결과 저장 위치: {VIDEO_OUT_DIR}/run/')

# %%
# Cell: 결과 영상에서 대표 프레임 미리보기 (균등 간격으로 N장)
import cv2
import glob
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Agg')

PREVIEW_N = 6  # 미리볼 프레임 수

# 저장된 결과 영상 찾기
saved_videos = glob.glob(os.path.join(VIDEO_OUT_DIR, 'run', '*.mp4')) + \
               glob.glob(os.path.join(VIDEO_OUT_DIR, 'run', '*.avi'))

if not saved_videos:
    print('결과 영상을 찾을 수 없습니다. 위 셀을 먼저 실행하세요.')
else:
    out_video_path = saved_videos[0]
    print('미리보기 대상:', out_video_path)

    cap = cv2.VideoCapture(out_video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fps          = cap.get(cv2.CAP_PROP_FPS)
    w            = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h            = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    print(f'총 프레임: {total_frames}  |  FPS: {fps:.1f}  |  해상도: {w}x{h}')

    # 균등 간격 프레임 인덱스 선택
    indices = [int(total_frames * i / PREVIEW_N) for i in range(PREVIEW_N)]

    frames = []
    for idx in indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if ret:
            frames.append((idx, frame[:, :, ::-1]))  # BGR → RGB
    cap.release()

    cols = 3
    rows = (len(frames) + cols - 1) // cols
    fig, axes = plt.subplots(rows, cols, figsize=(6 * cols, 4 * rows))
    axes = axes.flatten() if rows > 1 else [axes] if cols == 1 else axes.flatten()

    for i, (ax, (idx, img)) in enumerate(zip(axes, frames)):
        ax.imshow(img)
        ax.axis('off')
        t = idx / fps if fps > 0 else 0
        ax.set_title(f'frame {idx}  ({t:.1f}s)', fontsize=9)

    for ax in axes[len(frames):]:
        ax.set_visible(False)

    plt.suptitle(f'결과 영상 미리보기  |  conf ≥ {CONF_THRESHOLD}', fontsize=12, y=1.01)
    plt.tight_layout()
    plt.show()

# %%
# Cell: 웹캠 실시간 추론 (선택 사항)
# VSCode 터미널에서 실행하는 것을 권장합니다.
# Jupyter 셀에서 실행하면 창이 열리지 않을 수 있습니다.
#
# 사용법: 아래 코드 블록의 주석을 해제하고 실행하세요.
# 종료: 영상 창에서 'q' 키를 누르세요.

# import cv2
# from ultralytics import YOLO
#
# model = YOLO(MODEL_PATH)
#
# cap = cv2.VideoCapture(0)  # 0 = 기본 웹캠, 1·2 = 외부 카메라
# cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
# cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
#
# print('웹캠 추론 시작 — 창에서 q 키를 눌러 종료')
# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break
#
#     results = model.predict(frame, conf=CONF_THRESHOLD, verbose=False)
#     annotated = results[0].plot()
#
#     cv2.imshow('YOLO11m 실시간 추론  (q: 종료)', annotated)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
#
# cap.release()
# cv2.destroyAllWindows()
# print('종료')

print('웹캠 셀은 주석 처리된 상태입니다.')
print('사용하려면 위 주석(#)을 모두 해제하고 실행하세요.')
